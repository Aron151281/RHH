# %% [markdown]
# <a href="https://colab.research.google.com/github/Aron151281/RHH/blob/main/Projeto_ind_mod5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Um dos maiores desafios das organizações nos dias atuais é a destreza de se manter seu quadro de colaboradores e assim não perder o investimento que foi feito para formar e moldar esse funcionário para uma satisfação laboral a altura da empresa.
# Investimentos desse porte demanda tempo e muito recurso e por isso as empresas se veem em um dilema e por esse motivo meu setor foi acionado para que achasse uma solução atraves dos dados fornecidos atraves de uma planilha em arquivo excel e um gráfico fornecido pelo HRBP da empresa, diante disso irei fazer uma análise técnica e entregarei a solução aos resposáveis para tentar sanar esse problema na empresa.

# %% [markdown]
# ---

# %% [markdown]
# ![12.png](data:image/png;base64,...)

# %% [markdown]
#  Nesse gráfico ficou evidênciado que a falta de treinamento dado pela empresa era o maior motivo de desligamneto seguido de conflitos com superiores e outros funcionarios e em terceiro se tem a falta de reconhecimento junto a empresa, e o motivo que menos causa desligamentos são as molestias laborais .
#  Sendo assim podemos concluir atraves desse gráfico que a empresa pode investir mais em treinamnetos para as equipes podendo assim minimizar os três maiores motivos de desligamentos , pelo tal fato que se pode elaborar treinamentos que aproxime mais os trabalhadores e por consequência diminuindo os conflitos e por fim geraria uma satisfação de reconhecimento junto a empresa.

# %% [markdown]
# ---

# %% [markdown]
# ![13.png](data:image/png;base64,...)

# %% [markdown]
#  Esses dados foram fornecidos pelo parceiro de negocios de recursos humanos, e podemos verificar que a progreção na carreira , tipo de trabalho e a realocação  sao os maiores motivos de desligamento e novamente nesse grafico se verifica que o motivo de doença é o que menos impacta nesse cenario.
#  Uma solução para se melhorar seria uma modificação na cultura da empresa de plano de carreira , uma melhor seleção do RH referente as seletivas e uma modernização nos criterios de realocação .

# %% [markdown]
# ---

# %% [markdown]
# ![14.png](data:image/png;base64,...)

# %% [markdown]
# Esses dados foram gerados atraves de uma pesquisa no momento que os funcionarios eram desligados , abre se um alerta pela veracidade dos dados junto a realidade , nesse grafico disparado temos a progressão de carreira como o grande motivo dos desligamentos  , seguido de tipo de trabalho e falta de reconehcimento e dessa vez o que menos impactou foi o conflito com outros.
# Sendo assim com a leitura desse gráfico podemos concluir que Uma solução para se melhorar seria uma modificação na cultura da empresa de plano de carreira , uma melhor seleção do RH referente as seletivas e uma modernização nos criterios de realocação .

# %% [markdown]
# ---

# %% [markdown]
# ![11.png](data:image/png;base64,...)

# %% [markdown]
#  Nesse gráfico fizemos um comparativo dos dados e concluimos que os dados se assemelham e sendo assim fica evidente a veracidade de ambos os dados para uma tomada de decisão.

# %% [markdown]
# ## Conclusão:
#  - Com os gráficos podemos concluir que o motivo mais latente para o desligamento dos colaboradores tanto com dados do setor responsavel quanto uma pesquisa de saída é a perspectiva de um crescimento dentro da empresa gerando asim uma insatisfação e insegurança, uma possivel solução seria a implementação de planos de carreira dentro da empresa , isso impactaria na segunda e na terceira causa de maior desligamento que seriam tipo de trabalho e a falta reconhecimento.

# %% [markdown]
# ---

# %% [markdown]
# - O gráfico fornecido pelo HRBP é de entendimento limitado podendo gerar insight errôneo pela sua complexidade na visualização , para poucos dados fornecidos e uma objetividade na geração de gráficos , é usual os graficos de barras ou de linha que transpassa uma maior objetividade na explicação dos dados.
# Sendo assim uma elaboração de uma coleta dos dados com mais informações ajudaria na elaboração de graficos mais elaborados e objetivos que gerariam insight mais ricos sobre o assunto.
